# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create some mock data
t = [3, 5, 7, 9, 11, 13, 15]
box_map = [45.9, 46.2, 46.1, 46.2, 46.1, 45.8, 45.9]
mask_map = [41.3, 41.6, 41.5, 41.6, 41.6, 41.2, 41.5]

fig, ax = plt.subplots(1,1,figsize=(8,3))

color = 'tab:red'
ax.set_xlabel('kernel size at level 1', fontsize=16)
ax.set_ylabel('Mask mAP', fontsize=16)
plt.xticks(t)
plt.plot(t, mask_map, '-s', color=color)
plt.grid(True)

# ax1.plot(t, mask_map, color=color)
ax.tick_params(axis='y')

# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# print(mask_map)
# color = 'tab:blue'
# ax2.set_ylabel('Mask mAP', color=color)  # we already handled the x-label with ax1
# ax2.plot(t, mask_map, color=color)
# ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create some mock data
t = [3, 5, 7, 9, 11, 13, 15]
peak_mem = [4351, 4357, 4361, 4369, 4387, 4407, 4428]
train_tim = [8.5, 9.0, 9.5, 10.0, 10.5, 11.0, 12.0]

fig, ax = plt.subplots(1,1,figsize=(8,3))

color = 'tab:green'
ax.set_xlabel('kernel size at level 1', fontsize=16)
ax.set_ylabel('Peak Mem (G)', fontsize=16)
plt.xticks(t)
plt.plot(t, peak_mem, '-s', color=color)
plt.grid(True)

# ax1.plot(t, mask_map, color=color)
ax.tick_params(axis='y')

# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# print(mask_map)
# color = 'tab:blue'
# ax2.set_ylabel('Mask mAP', color=color)  # we already handled the x-label with ax1
# ax2.plot(t, mask_map, color=color)
# ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
